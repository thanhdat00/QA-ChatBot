# %%
from pymilvus import (
    connections,
    Collection,
    FieldSchema,
    CollectionSchema,
    DataType,
    utility,
)
import pandas as pd
from scipy import sparse
import numpy as np

connections.connect(uri="http://localhost:19530")  # Replace with your Milvus server IP

# %%
# utility.drop_collection("thu_vien_phap_luat")

# %%
fields = [
    FieldSchema(name="id", dtype=DataType.INT64, is_primary=True, auto_id=True),
    FieldSchema(name="url", dtype=DataType.VARCHAR, max_length=8012),
    FieldSchema(name="title_dense", dtype=DataType.FLOAT_VECTOR, dim=1024),
    FieldSchema(name="title_sparse", dtype=DataType.SPARSE_FLOAT_VECTOR),
    FieldSchema(name="title_text", dtype=DataType.VARCHAR, max_length=8012),
    FieldSchema(name="content_dense", dtype=DataType.FLOAT_VECTOR, dim=1024),
    FieldSchema(name="content_sparse", dtype=DataType.SPARSE_FLOAT_VECTOR),
    FieldSchema(name="content_text", dtype=DataType.VARCHAR, max_length=8012),
]

schema = CollectionSchema(fields=fields, enable_dynamic_field=False)

collection = Collection(name="thu_vien_phap_luat", schema=schema)

# %%
dense_index = {
    "index_type": "HNSW",
    "metric_type": "COSINE",
    "M": 64,
    "efConstruction": 80,
}
collection.create_index("title_dense", dense_index)
collection.create_index("content_dense", dense_index)

sparse_index = {
    "index_type": "SPARSE_WAND",
    "metric_type": "IP",
}
collection.create_index("title_sparse", sparse_index)
collection.create_index("content_sparse", sparse_index)
# Out:
# Status(code=0, message=)

# %%
from glob import glob

folders = glob("../features/*")
folders.sort()
folders
# Out:
# ['../features\\p0-9999',
#  '../features\\p10000-19999',
#  '../features\\p20000-29999',
#  '../features\\p30000-39999',
#  '../features\\p50000-59999',
#  '../features\\p60000-69999',
#  '../features\\p70000-79999']

# %%
def load_data(folder):
    df = pd.read_parquet(f"{folder}/encoded_data.parquet")
    title_sparse = sparse.load_npz(f"{folder}/title_sparse.npz")
    df["title_sparse"] = list(title_sparse)

    df = df.explode("content_text")
    content_sparse = sparse.load_npz(f"{folder}/content_sparse.npz")

    with open(f"{folder}/content_dense.npy", "rb") as file:
        content_dense = np.load(file)

    df["content_sparse"] = list(content_sparse)
    df["content_dense"] = list(content_dense)
    return df

# %%
def insert_to_collection(df, collection, batch_size=1000):
    for i in range(0, len(df), batch_size):
        print(f"Inserting {i}-{i+batch_size}...")
        collection.insert(
            df.iloc[i : i + batch_size][
                [
                    "url",
                    "title_sparse",
                    "title_dense",
                    "title",
                    "content_sparse",
                    "content_dense",
                    "content_text",
                ]
            ]
            .rename(columns={"title": "title_text"})
            .to_dict("records")
        )

# %%
for folder in folders:
    df = load_data(folder)
    print(folder, df.shape)
    insert_to_collection(df, collection)
    print("complete inserted df")
    print()
    # break
# Out:
# ../features\p10000-19999 (85206, 11)
# Inserting 0-1000...
# Inserting 1000-2000...
# Inserting 2000-3000...
# Inserting 3000-4000...
# Inserting 4000-5000...
# Inserting 5000-6000...
# Inserting 6000-7000...
# Inserting 7000-8000...
# Inserting 8000-9000...
# Inserting 9000-10000...
# Inserting 10000-11000...
# Inserting 11000-12000...
# Inserting 12000-13000...
# Inserting 13000-14000...
# Inserting 14000-15000...
# Inserting 15000-16000...
# Inserting 16000-17000...
# Inserting 17000-18000...
# Inserting 18000-19000...
# Inserting 19000-20000...
# Inserting 20000-21000...
# Inserting 21000-22000...
# Inserting 22000-23000...
# Inserting 23000-24000...
# Inserting 24000-25000...
# Inserting 25000-26000...
# Inserting 26000-27000...
# Inserting 27000-28000...
# Inserting 28000-29000...
# Inserting 29000-30000...
# Inserting 30000-31000...
# Inserting 31000-32000...
# Inserting 32000-33000...
# Inserting 33000-34000...
# Inserting 34000-35000...
# Inserting 35000-36000...
# Inserting 36000-37000...
# Inserting 37000-38000...
# Inserting 38000-39000...
# Inserting 39000-40000...
# Inserting 40000-41000...
# Inserting 41000-42000...
# Inserting 42000-43000...
# Inserting 43000-44000...
# Inserting 44000-45000...
# Inserting 45000-46000...
# Inserting 46000-47000...
# Inserting 47000-48000...
# Inserting 48000-49000...
# Inserting 49000-50000...
# Inserting 50000-51000...
# Inserting 51000-52000...
# Inserting 52000-53000...
# Inserting 53000-54000...
# Inserting 54000-55000...
# Inserting 55000-56000...
# Inserting 56000-57000...
# Inserting 57000-58000...
# Inserting 58000-59000...
# Inserting 59000-60000...
# Inserting 60000-61000...
# Inserting 61000-62000...
# Inserting 62000-63000...
# Inserting 63000-64000...
# Inserting 64000-65000...
# Inserting 65000-66000...
# Inserting 66000-67000...
# Inserting 67000-68000...
# Inserting 68000-69000...
# Inserting 69000-70000...
# Inserting 70000-71000...
# Inserting 71000-72000...
# Inserting 72000-73000...
# Inserting 73000-74000...
# Inserting 74000-75000...
# Inserting 75000-76000...
# Inserting 76000-77000...
# Inserting 77000-78000...
# Inserting 78000-79000...
# Inserting 79000-80000...
# Inserting 80000-81000...
# Inserting 81000-82000...
# Inserting 82000-83000...
# Inserting 83000-84000...
# Inserting 84000-85000...
# Inserting 85000-86000...
# complete inserted df
#
# ../features\p20000-29999 (76356, 11)
# Inserting 0-1000...
# Inserting 1000-2000...
# Inserting 2000-3000...
# Inserting 3000-4000...
# Inserting 4000-5000...
# Inserting 5000-6000...
# Inserting 6000-7000...
# Inserting 7000-8000...
# Inserting 8000-9000...
# Inserting 9000-10000...
# Inserting 10000-11000...
# Inserting 11000-12000...
# Inserting 12000-13000...
# Inserting 13000-14000...
# Inserting 14000-15000...
# Inserting 15000-16000...
# Inserting 16000-17000...
# Inserting 17000-18000...
# Inserting 18000-19000...
# Inserting 19000-20000...
# Inserting 20000-21000...
# Inserting 21000-22000...
# Inserting 22000-23000...
# Inserting 23000-24000...
# Inserting 24000-25000...
# Inserting 25000-26000...
# Inserting 26000-27000...
# Inserting 27000-28000...
# Inserting 28000-29000...
# Inserting 29000-30000...
# Inserting 30000-31000...
# Inserting 31000-32000...
# Inserting 32000-33000...
# Inserting 33000-34000...
# Inserting 34000-35000...
# Inserting 35000-36000...
# Inserting 36000-37000...
# Inserting 37000-38000...
# Inserting 38000-39000...
# Inserting 39000-40000...
# Inserting 40000-41000...
# Inserting 41000-42000...
# Inserting 42000-43000...
# Inserting 43000-44000...
# Inserting 44000-45000...
# Inserting 45000-46000...
# Inserting 46000-47000...
# Inserting 47000-48000...
# Inserting 48000-49000...
# Inserting 49000-50000...
# Inserting 50000-51000...
# Inserting 51000-52000...
# Inserting 52000-53000...
# Inserting 53000-54000...
# Inserting 54000-55000...
# Inserting 55000-56000...
# Inserting 56000-57000...
# Inserting 57000-58000...
# Inserting 58000-59000...
# Inserting 59000-60000...
# Inserting 60000-61000...
# Inserting 61000-62000...
# Inserting 62000-63000...
# Inserting 63000-64000...
# Inserting 64000-65000...
# Inserting 65000-66000...
# Inserting 66000-67000...
# Inserting 67000-68000...
# Inserting 68000-69000...
# Inserting 69000-70000...
# Inserting 70000-71000...
# Inserting 71000-72000...
# Inserting 72000-73000...
# Inserting 73000-74000...
# Inserting 74000-75000...
# Inserting 75000-76000...
# Inserting 76000-77000...
# complete inserted df
#
# ../features\p30000-39999 (85798, 11)
# Inserting 0-1000...
# Inserting 1000-2000...
# Inserting 2000-3000...
# Inserting 3000-4000...
# Inserting 4000-5000...
# Inserting 5000-6000...
# Inserting 6000-7000...
# Inserting 7000-8000...
# Inserting 8000-9000...
# Inserting 9000-10000...
# Inserting 10000-11000...
# Inserting 11000-12000...
# Inserting 12000-13000...
# Inserting 13000-14000...
# Inserting 14000-15000...
# Inserting 15000-16000...
# Inserting 16000-17000...
# Inserting 17000-18000...
# Inserting 18000-19000...
# Inserting 19000-20000...
# Inserting 20000-21000...
# Inserting 21000-22000...
# Inserting 22000-23000...
# Inserting 23000-24000...
# Inserting 24000-25000...
# Inserting 25000-26000...
# Inserting 26000-27000...
# Inserting 27000-28000...
# Inserting 28000-29000...
# Inserting 29000-30000...
# Inserting 30000-31000...
# Inserting 31000-32000...
# Inserting 32000-33000...
# Inserting 33000-34000...
# Inserting 34000-35000...
# Inserting 35000-36000...
# Inserting 36000-37000...
# Inserting 37000-38000...
# Inserting 38000-39000...
# Inserting 39000-40000...
# Inserting 40000-41000...
# Inserting 41000-42000...
# Inserting 42000-43000...
# Inserting 43000-44000...
# Inserting 44000-45000...
# Inserting 45000-46000...
# Inserting 46000-47000...
# Inserting 47000-48000...
# Inserting 48000-49000...
# Inserting 49000-50000...
# Inserting 50000-51000...
# Inserting 51000-52000...
# Inserting 52000-53000...
# Inserting 53000-54000...
# Inserting 54000-55000...
# Inserting 55000-56000...
# Inserting 56000-57000...
# RPC error: [describe_collection], <MilvusException: (code=<bound method _MultiThreadedRendezvous.code of <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.
#  -- 10061)"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.\r\n -- 10061)", grpc_status:14, created_time:"2024-09-26T19:00:43.3314423+00:00"}"
# >>, message=Retry run out of 75 retry times, message=failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.
#  -- 10061))>, <Time:{'RPC start': '2024-09-27 01:57:06.745112', 'RPC error': '2024-09-27 02:00:43.352980'}>
# RPC error: [insert_rows], <MilvusException: (code=<bound method _MultiThreadedRendezvous.code of <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.
#  -- 10061)"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.\r\n -- 10061)", grpc_status:14, created_time:"2024-09-26T19:00:43.3314423+00:00"}"
# >>, message=Retry run out of 75 retry times, message=failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.
#  -- 10061))>, <Time:{'RPC start': '2024-09-27 01:55:36.176277', 'RPC error': '2024-09-27 02:00:43.435177'}>
# ---------------------------------------------------------------------------
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[8], line 4
#       3 print(folder, df.shape)
# ----> 4 insert_to_collection(df, collection)
#       5 print("complete inserted df")
#
# Cell In[7], line 4, in insert_to_collection(df, collection, batch_size)
#       3 print(f"Inserting {i}-{i+batch_size}...")
# ----> 4 collection.insert(
#       5     df.iloc[i : i + batch_size][
#       6         [
#       7             "url",
#       8             "title_sparse",
#       9             "title_dense",
#      10             "title",
#      11             "content_sparse",
#      12             "content_dense",
#      13             "content_text",
#      14         ]
#      15     ]
#      16     .rename(columns={"title": "title_text"})
#      17     .to_dict("records")
#      18 )
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\orm\collection.py:503, in Collection.insert(self, data, partition_name, timeout, **kwargs)
#     502 if is_row_based(data):
# --> 503     return conn.insert_rows(
#     504         collection_name=self._name,
#     505         entities=data,
#     506         partition_name=partition_name,
#     507         timeout=timeout,
#     508         schema=self._schema_dict,
#     509         **kwargs,
#     510     )
#     512 check_insert_schema(self.schema, data)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:148, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     147     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 148     raise e from e
#     149 except grpc.FutureTimeoutError as e:
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:144, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     143     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 144     return func(*args, **kwargs)
#     145 except MilvusException as e:
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:183, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     182     self.set_onetime_request_id(req_id)
# --> 183 return func(self, *args, **kwargs)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:123, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     122     else:
# --> 123         raise e from e
#     124 except Exception as e:
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:87, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      86 try:
# ---> 87     return func(*args, **kwargs)
#      88 except grpc.RpcError as e:
#      89     # Do not retry on these codes
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\client\grpc_handler.py:492, in GrpcHandler.insert_rows(self, collection_name, entities, partition_name, schema, timeout, **kwargs)
#     482 @retry_on_rpc_failure()
#     483 def insert_rows(
#     484     self,
#    (...)
#     490     **kwargs,
#     491 ):
# --> 492     request = self._prepare_row_insert_request(
#     493         collection_name, entities, partition_name, timeout, **kwargs
#     494     )
#     495     resp = self._stub.Insert(request=request, timeout=timeout)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\client\grpc_handler.py:513, in GrpcHandler._prepare_row_insert_request(self, collection_name, entity_rows, partition_name, schema, timeout, **kwargs)
#     512 if not isinstance(schema, dict):
# --> 513     schema = self.describe_collection(collection_name, timeout=timeout)
#     515 fields_info = schema.get("fields")
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:148, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     147     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 148     raise e from e
#     149 except grpc.FutureTimeoutError as e:
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:144, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     143     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 144     return func(*args, **kwargs)
#     145 except MilvusException as e:
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:183, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     182     self.set_onetime_request_id(req_id)
# --> 183 return func(self, *args, **kwargs)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:93, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      92 if timeout(start_time):
# ---> 93     raise MilvusException(e.code, f"{to_msg}, message={e.details()}") from e
#      95 if counter > 3:
#
# MilvusException: <MilvusException: (code=<bound method _MultiThreadedRendezvous.code of <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.
#  -- 10061)"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.\r\n -- 10061)", grpc_status:14, created_time:"2024-09-26T19:00:43.3314423+00:00"}"
# >>, message=Retry run out of 75 retry times, message=failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.
#  -- 10061))>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[8], line 4
#       3 print(folder, df.shape)
# ----> 4 insert_to_collection(df, collection)
#       5 print("complete inserted df")
#
# Cell In[7], line 4, in insert_to_collection(df, collection, batch_size)
#       3 print(f"Inserting {i}-{i+batch_size}...")
# ----> 4 collection.insert(
#       5     df.iloc[i : i + batch_size][
#       6         [
#       7             "url",
#       8             "title_sparse",
#       9             "title_dense",
#      10             "title",
#      11             "content_sparse",
#      12             "content_dense",
#      13             "content_text",
#      14         ]
#      15     ]
#      16     .rename(columns={"title": "title_text"})
#      17     .to_dict("records")
#      18 )
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\orm\collection.py:503, in Collection.insert(self, data, partition_name, timeout, **kwargs)
#     502 if is_row_based(data):
# --> 503     return conn.insert_rows(
#     504         collection_name=self._name,
#     505         entities=data,
#     506         partition_name=partition_name,
#     507         timeout=timeout,
#     508         schema=self._schema_dict,
#     509         **kwargs,
#     510     )
#     512 check_insert_schema(self.schema, data)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:148, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     147     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 148     raise e from e
#     149 except grpc.FutureTimeoutError as e:
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:144, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     143     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 144     return func(*args, **kwargs)
#     145 except MilvusException as e:
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:183, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     182     self.set_onetime_request_id(req_id)
# --> 183 return func(self, *args, **kwargs)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:123, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     122     else:
# --> 123         raise e from e
#     124 except Exception as e:
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:87, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      86 try:
# ---> 87     return func(*args, **kwargs)
#      88 except grpc.RpcError as e:
#      89     # Do not retry on these codes
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\client\grpc_handler.py:492, in GrpcHandler.insert_rows(self, collection_name, entities, partition_name, schema, timeout, **kwargs)
#     482 @retry_on_rpc_failure()
#     483 def insert_rows(
#     484     self,
#    (...)
#     490     **kwargs,
#     491 ):
# --> 492     request = self._prepare_row_insert_request(
#     493         collection_name, entities, partition_name, timeout, **kwargs
#     494     )
#     495     resp = self._stub.Insert(request=request, timeout=timeout)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\client\grpc_handler.py:513, in GrpcHandler._prepare_row_insert_request(self, collection_name, entity_rows, partition_name, schema, timeout, **kwargs)
#     512 if not isinstance(schema, dict):
# --> 513     schema = self.describe_collection(collection_name, timeout=timeout)
#     515 fields_info = schema.get("fields")
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:148, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     147     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 148     raise e from e
#     149 except grpc.FutureTimeoutError as e:
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:144, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     143     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 144     return func(*args, **kwargs)
#     145 except MilvusException as e:
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:183, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     182     self.set_onetime_request_id(req_id)
# --> 183 return func(self, *args, **kwargs)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:93, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      92 if timeout(start_time):
# ---> 93     raise MilvusException(e.code, f"{to_msg}, message={e.details()}") from e
#      95 if counter > 3:
#
# MilvusException: <MilvusException: (code=<bound method _MultiThreadedRendezvous.code of <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.
#  -- 10061)"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.\r\n -- 10061)", grpc_status:14, created_time:"2024-09-26T19:00:43.3314423+00:00"}"
# >>, message=Retry run out of 75 retry times, message=failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.
#  -- 10061))>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
# Cell In[8], line 4
#       2 df = load_data(folder)
#       3 print(folder, df.shape)
# ----> 4 insert_to_collection(df, collection)
#       5 print("complete inserted df")
#       6 print()
#
# Cell In[7], line 4, in insert_to_collection(df, collection, batch_size)
#       2 for i in range(0, len(df), batch_size):
#       3     print(f"Inserting {i}-{i+batch_size}...")
# ----> 4     collection.insert(
#       5         df.iloc[i : i + batch_size][
#       6             [
#       7                 "url",
#       8                 "title_sparse",
#       9                 "title_dense",
#      10                 "title",
#      11                 "content_sparse",
#      12                 "content_dense",
#      13                 "content_text",
#      14             ]
#      15         ]
#      16         .rename(columns={"title": "title_text"})
#      17         .to_dict("records")
#      18     )
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\orm\collection.py:503, in Collection.insert(self, data, partition_name, timeout, **kwargs)
#     501 conn = self._get_connection()
#     502 if is_row_based(data):
# --> 503     return conn.insert_rows(
#     504         collection_name=self._name,
#     505         entities=data,
#     506         partition_name=partition_name,
#     507         timeout=timeout,
#     508         schema=self._schema_dict,
#     509         **kwargs,
#     510     )
#     512 check_insert_schema(self.schema, data)
#     513 entities = Prepare.prepare_data(data, self.schema)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:148, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     146     record_dict["RPC error"] = str(datetime.datetime.now())
#     147     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 148     raise e from e
#     149 except grpc.FutureTimeoutError as e:
#     150     record_dict["gRPC timeout"] = str(datetime.datetime.now())
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:144, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     142 try:
#     143     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 144     return func(*args, **kwargs)
#     145 except MilvusException as e:
#     146     record_dict["RPC error"] = str(datetime.datetime.now())
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:183, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     181 if req_id:
#     182     self.set_onetime_request_id(req_id)
# --> 183 return func(self, *args, **kwargs)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:123, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     121         back_off = min(back_off * back_off_multiplier, max_back_off)
#     122     else:
# --> 123         raise e from e
#     124 except Exception as e:
#     125     raise e from e
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:87, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      85 while True:
#      86     try:
# ---> 87         return func(*args, **kwargs)
#      88     except grpc.RpcError as e:
#      89         # Do not retry on these codes
#      90         if e.code() in IGNORE_RETRY_CODES:
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\client\grpc_handler.py:492, in GrpcHandler.insert_rows(self, collection_name, entities, partition_name, schema, timeout, **kwargs)
#     482 @retry_on_rpc_failure()
#     483 def insert_rows(
#     484     self,
#    (...)
#     490     **kwargs,
#     491 ):
# --> 492     request = self._prepare_row_insert_request(
#     493         collection_name, entities, partition_name, timeout, **kwargs
#     494     )
#     495     resp = self._stub.Insert(request=request, timeout=timeout)
#     496     check_status(resp.status)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\client\grpc_handler.py:513, in GrpcHandler._prepare_row_insert_request(self, collection_name, entity_rows, partition_name, schema, timeout, **kwargs)
#     510     entity_rows = [entity_rows]
#     512 if not isinstance(schema, dict):
# --> 513     schema = self.describe_collection(collection_name, timeout=timeout)
#     515 fields_info = schema.get("fields")
#     516 enable_dynamic = schema.get("enable_dynamic_field", False)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:148, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     146     record_dict["RPC error"] = str(datetime.datetime.now())
#     147     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 148     raise e from e
#     149 except grpc.FutureTimeoutError as e:
#     150     record_dict["gRPC timeout"] = str(datetime.datetime.now())
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:144, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     142 try:
#     143     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 144     return func(*args, **kwargs)
#     145 except MilvusException as e:
#     146     record_dict["RPC error"] = str(datetime.datetime.now())
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:183, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     181 if req_id:
#     182     self.set_onetime_request_id(req_id)
# --> 183 return func(self, *args, **kwargs)
#
# File c:\Users\daoqu\AppData\Local\Programs\Python\Python310\lib\site-packages\pymilvus\decorators.py:93, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      91     raise e from e
#      92 if timeout(start_time):
# ---> 93     raise MilvusException(e.code, f"{to_msg}, message={e.details()}") from e
#      95 if counter > 3:
#      96     retry_msg = (
#      97         f"[{func.__name__}] retry:{counter}, cost: {back_off:.2f}s, "
#      98         f"reason: <{e.__class__.__name__}: {e.code()}, {e.details()}>"
#      99     )
#
# MilvusException: <MilvusException: (code=<bound method _MultiThreadedRendezvous.code of <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.
#  -- 10061)"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.\r\n -- 10061)", grpc_status:14, created_time:"2024-09-26T19:00:43.3314423+00:00"}"
# >>, message=Retry run out of 75 retry times, message=failed to connect to all addresses; last error: UNAVAILABLE: ipv6:%5B::1%5D:19530: ConnectEx: Connection refused (No connection could be made because the target machine actively refused it.
#  -- 10061))>
